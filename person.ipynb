# %% [raw]
# !pwd
# !python3 train.py --data data/person.yaml --weights models/yolov5m6.pt --cfg ./models/hub/yolov5m6.yaml --batch-size=3 \
# --epochs=10 --hyp data/hyps/hyp.scratch-low.yaml --project ../runs --exist-ok

# %%
# !sh r.sh
# Out:
# train: weights=./best.pt, cfg=./models/hub/yolov5m6.yaml, data=data/person.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=3, imgsz=1280, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=../runs, name=exp, exist_ok=True, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (offline), for updates see https://github.com/ultralytics/yolov5
# requirements: YOLOv5 requirement "thop>=0.1.1" not found, attempting AutoUpdate...
# requirements: AutoUpdate skipped (offline)
# YOLOv5 🚀 v6.2-109-g23701ea Python-3.7.5 torch-1.10.0+cu102 CUDA:0 (GeForce RTX 2080 Ti, 11019MiB)
#
# ...

# %%
sh /project/train/src_repo/r.sh
